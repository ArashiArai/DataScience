# %%
#uv add pillow
import google.generativeai as genai
from PIL import Image


client = genai.Client(api_key="AIzaSyBOFqvGnNSL12l8B5dGEXh2nNDf4tzwQzc")


# 1. Load your local image
# Ensure you have 'sample_image.jpg' in your project folder
image = Image.open('acmelogo.jpg')

# 2. Define your multimodal prompt
prompt = "Please provide a detailed description of this image and relate its mood to a poem by Rabindranath Tagore."

    
try:
    response = client.models.generate_content(
            model='gemini-3-flash-preview',
            contents=prompt
        )
    print(response.text)
except Exception as e:
    print(f"Error calling Gemini: {e}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 6
#       2 import google.generativeai as genai
#       3 from PIL import Image
# ----> 6 client = genai.Client(api_key="AIzaSyBOFqvGnNSL12l8B5dGEXh2nNDf4tzwQzc")
#       9 # 1. Load your local image
#      10 # Ensure you have 'sample_image.jpg' in your project folder
#      11 image = Image.open('acmelogo.jpg')
#
# AttributeError: module 'google.generativeai' has no attribute 'Client'

# %%
import google.generativeai as genai
from PIL import Image

# Configure API key
genai.configure(api_key="AIzaSyBOFqvGnNSL12l8B5dGEXh2nNDf4tzwQzc")

# Load image
image = Image.open('acmelogo.jpg')

# Prompt
prompt = "Please provide a detailed description of this image and relate its mood to a poem by Rabindranath Tagore."

# Create model
model = genai.GenerativeModel('gemini-1.5-flash')

try:
    response = model.generate_content([prompt, image])
    print(response.text)
except Exception as e:
    print(f"Error calling Gemini: {e}")
# Out:
# Error calling Gemini: 404 models/gemini-1.5-flash is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods.
